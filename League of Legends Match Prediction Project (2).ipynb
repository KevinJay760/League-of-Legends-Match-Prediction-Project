# %% [markdown]
# # Predicting (Past) Professional League of Legends Matches with Sklearn

# %%
#Importing relevant packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import svm
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
#Exploring the data, we can see there are 45,489 rows with 103 columns each.

# %%
data = pd.read_csv('2020_LoL_esports_match_data_from_OraclesElixir_20200714.csv')
data
# Out:
#                       gameid datacompleteness  \
# 0      ESPORTSTMNT03/1241318         complete
# 1      ESPORTSTMNT03/1241318         complete
# 2      ESPORTSTMNT03/1241318         complete
# 3      ESPORTSTMNT03/1241318         complete
# 4      ESPORTSTMNT03/1241318         complete
# ...                      ...              ...
# 45484  ESPORTSTMNT03/1414873         complete
# 45485  ESPORTSTMNT03/1414873         complete
# 45486  ESPORTSTMNT03/1414873         complete
# 45487  ESPORTSTMNT03/1414873         complete
# 45488  ESPORTSTMNT03/1414873         complete
#
#                                                      url league  year split  \
# 0      http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 1      http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 2      http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 3      http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 4      http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# ...                                                  ...    ...   ...   ...
# 45484  http://matchhistory.na.leagueoflegends.com/en/...   BRCC  2020   NaN
# 45485  http://matchhistory.na.leagueoflegends.com/en/...   BRCC  2020   NaN
# 45486  http://matchhistory.na.leagueoflegends.com/en/...   BRCC  2020   NaN
# 45487  http://matchhistory.na.leagueoflegends.com/en/...   BRCC  2020   NaN
# 45488  http://matchhistory.na.leagueoflegends.com/en/...   BRCC  2020   NaN
#
#        playoffs                 date  game  patch  ...  csdiffat10 goldat15  \
# 0             0  2020-01-03 07:33:26     1   9.24  ...        23.0   4888.0
# 1             0  2020-01-03 07:33:26     1   9.24  ...       -10.0   4385.0
# 2             0  2020-01-03 07:33:26     1   9.24  ...        -9.0   4809.0
# 3             0  2020-01-03 07:33:26     1   9.24  ...         3.0   4915.0
# 4             0  2020-01-03 07:33:26     1   9.24  ...         1.0   2956.0
# ...         ...                  ...   ...    ...  ...         ...      ...
# 45484         0  2020-07-14 01:49:46     1  10.13  ...        -6.0   5342.0
# 45485         0  2020-07-14 01:49:46     1  10.13  ...        17.0   5455.0
# 45486         0  2020-07-14 01:49:46     1  10.13  ...         2.0   3234.0
# 45487         0  2020-07-14 01:49:46     1  10.13  ...         5.0  22022.0
# 45488         0  2020-07-14 01:49:46     1  10.13  ...        -5.0  23240.0
#
#         xpat15 csat15 opp_goldat15 opp_xpat15 opp_csat15 golddiffat15  \
# 0       7368.0  131.0       4723.0     7202.0      118.0        165.0
# 1       4817.0   91.0       4784.0     4667.0       98.0       -399.0
# 2       6275.0  129.0       5218.0     8112.0      140.0       -409.0
# 3       4959.0  136.0       4864.0     5360.0      135.0         51.0
# 4       3800.0   20.0       3189.0     3543.0       28.0       -233.0
# ...        ...    ...          ...        ...        ...          ...
# 45484   7496.0  130.0       4875.0     6756.0      138.0        467.0
# 45485   4877.0  138.0       4555.0     4448.0      117.0        900.0
# 45486   3747.0   25.0       3071.0     3789.0       20.0        163.0
# 45487  27605.0  498.0      23240.0    28287.0      512.0      -1218.0
# 45488  28287.0  512.0      22022.0    27605.0      498.0       1218.0
#
#       xpdiffat15 csdiffat15
# 0          166.0       13.0
# 1          150.0       -7.0
# 2        -1837.0      -11.0
# 3         -401.0        1.0
# 4          257.0       -8.0
# ...          ...        ...
# 45484      740.0       -8.0
# 45485      429.0       21.0
# 45486      -42.0        5.0
# 45487     -682.0      -14.0
# 45488      682.0       14.0
#
# [45489 rows x 103 columns]

# %%
#A quick view of some of the columns.

# %%
data.columns[0:40]
# Out:
# Index(['gameid', 'datacompleteness', 'url', 'league', 'year', 'split',
#        'playoffs', 'date', 'game', 'patch', 'playerid', 'side', 'position',
#        'player', 'team', 'champion', 'ban1', 'ban2', 'ban3', 'ban4', 'ban5',
#        'gamelength', 'result', 'kills', 'deaths', 'assists', 'teamkills',
#        'teamdeaths', 'doublekills', 'triplekills', 'quadrakills', 'pentakills',
#        'firstblood', 'firstbloodkill', 'firstbloodassist', 'firstbloodvictim',
#        'team kpm', 'ckpm', 'firstdragon', 'dragons'],
#       dtype='object')

# %%
#Filtering the data to only include "complete" rows.

# %%
data_cleaned = data[data.get('datacompleteness') == 'complete']

# %%
#Dropping irrelevant columns to our prediction.

# %%
data_cleaned = data_cleaned.drop(['datacompleteness','url','league','year','split','playoffs','date','game','patch','playerid','position','player','team','gameid','side','ban1','ban2','ban3','ban4','ban5','champion'],axis=1)

# %%
#The data still has a decent amount of missing values, even after filtering for completeness.
#Dropping columns with over 20,000 missing values.

# %%
a = data_cleaned.isnull().sum().sort_values(ascending=False) < 20000
b = a[a == True].index
data_cleaned = data_cleaned[b]

# %%
#Eliminating final missing values by dropping rows which contain any NaN values.

# %%
data_cleaned = data_cleaned.dropna(axis=0)
data_cleaned
# Out:
#        firstbloodvictim  firstbloodassist  csdiffat15  opp_inhibitors  \
# 0                   0.0               0.0        13.0             0.0
# 1                   0.0               0.0        -7.0             0.0
# 2                   1.0               0.0       -11.0             0.0
# 3                   0.0               0.0         1.0             0.0
# 4                   0.0               0.0        -8.0             0.0
# ...                 ...               ...         ...             ...
# 45482               0.0               0.0        -1.0             0.0
# 45483               0.0               1.0        -3.0             0.0
# 45484               0.0               0.0        -8.0             0.0
# 45485               0.0               0.0        21.0             0.0
# 45486               0.0               1.0         5.0             0.0
#
#        triplekills  doublekills  xpdiffat15  inhibitors  opp_xpat10  \
# 0              0.0          0.0       166.0         1.0      4432.0
# 1              0.0          1.0       150.0         0.0      3010.0
# 2              0.0          0.0     -1837.0         0.0      4861.0
# 3              0.0          2.0      -401.0         0.0      3250.0
# 4              0.0          0.0       257.0         0.0      2429.0
# ...            ...          ...         ...         ...         ...
# 45482          1.0          2.0       145.0         0.0      4523.0
# 45483          0.0          0.0      -590.0         0.0      3650.0
# 45484          0.0          0.0       740.0         2.0      4382.0
# 45485          0.0          1.0       429.0         0.0      2923.0
# 45486          0.0          0.0       -42.0         0.0      2198.0
#
#        goldspent  ...  wardskilled  earnedgold  totalgold  teamdeaths  \
# 0        11350.0  ...          3.0      8498.0    13302.0          11
# 1        12175.0  ...         26.0      8680.0    13484.0          11
# 2        14225.0  ...         32.0     10615.0    15419.0          11
# 3        16500.0  ...         30.0     14079.0    18883.0          11
# 4         8025.0  ...          6.0      3035.0     7839.0          11
# ...          ...  ...          ...         ...        ...         ...
# 45482    11495.0  ...          6.0      9085.0    13008.0           4
# 45483     8725.0  ...          6.0      5528.0     9451.0           4
# 45484    11025.0  ...          5.0      7928.0    11851.0           4
# 45485    12200.0  ...          4.0      8859.0    12782.0           4
# 45486     7350.0  ...         15.0      4370.0     8293.0           4
#
#        teamkills  assists  deaths  kills  result  gamelength
# 0             17        7       3      0       1        2220
# 1             17        9       0      4       1        2220
# 2             17        5       2      5       1        2220
# 3             17        9       1      7       1        2220
# 4             17        3       5      1       1        2220
# ...          ...      ...     ...    ...     ...         ...
# 45482         18        4       1      9       1        1788
# 45483         18       10       2      0       1        1788
# 45484         18        7       0      1       1        1788
# 45485         18        5       0      6       1        1788
# 45486         18       15       1      2       1        1788
#
# [27547 rows x 58 columns]

# %%
#Isolating the dependant variable (y) and removing it from the independant variables we will use for prediction (X).

# %%
X = data_cleaned.drop('result',axis=1)
y = data_cleaned[['result']]

# %%
#Seperating the data into testing and training sets to prepare it for the model.

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 0)

# %%
#Issues can arise within our model when there are big differences in the scale of respective columns.
#For example, the total gold is usually in the thousands, whereas the amount of inhibitors taken is one or two.

# %%
#To standardize the X data, we use StandardScaler.

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#A quick look at the transformed, standardized training data.

# %%
X_train
# Out:
# array([[-3.31506789e-01, -4.20715520e-01,  1.89428411e-01, ...,
#          1.32566803e+00, -1.01655661e+00,  1.50527000e+00],
#        [-3.31506789e-01,  2.37690304e+00,  4.86930224e-01, ...,
#         -2.88232220e-01, -1.01655661e+00, -2.51129030e-01],
#        [-3.31506789e-01, -4.20715520e-01,  3.48977714e-03, ...,
#         -8.26198971e-01,  1.78825437e-01,  2.27888889e-01],
#        ...,
#        [-3.31506789e-01,  2.37690304e+00,  5.98493404e-01, ...,
#         -8.26198971e-01,  1.78825437e-01,  3.49697608e+00],
#        [-3.31506789e-01,  2.37690304e+00, -2.19636583e-01, ...,
#         -8.26198971e-01, -6.18095931e-01, -1.55652289e+00],
#        [-3.31506789e-01, -4.20715520e-01,  1.63974975e+00, ...,
#          2.49734531e-01, -2.19635247e-01,  2.81113102e-01]])

# %%
#Training the model using RandomForestClassifier.

# %%
rfc = RandomForestClassifier(n_estimators = 800)
rfc.fit(X_train,y_train)
pred_rfc = rfc.predict(X_test)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
#A quick look at the accuracy of our predicted results.
#97% of wins and 96% of losses are correctly calculated.

# %%
print(classification_report(y_test,pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      2774
#            1       0.97      0.96      0.96      2736
#
#     accuracy                           0.97      5510
#    macro avg       0.97      0.97      0.97      5510
# weighted avg       0.97      0.97      0.97      5510

# %%
#Looking at which features the model weighted strongly.
#It appears the model found teamdeaths, team kpm, and teamkills as the strongest predictors of the result of the match.

# %%
feature_list = X.columns
importances = np.array(rfc.feature_importances_)
pd.DataFrame().assign(Feature = feature_list,Importance = importances).set_index('Feature').sort_values('Importance',ascending=False)
# Out:
#                          Importance
# Feature
# teamdeaths                 0.214261
# teamkills                  0.162198
# team kpm                   0.158863
# assists                    0.073336
# deaths                     0.065245
# ckpm                       0.034513
# opp_inhibitors             0.031854
# earned gpm                 0.026867
# inhibitors                 0.026239
# earnedgold                 0.016813
# kills                      0.013804
# earnedgoldshare            0.011918
# totalgold                  0.009970
# golddiffat15               0.009553
# monsterkillsenemyjungle    0.008708
# gamelength                 0.008522
# goldspent                  0.005974
# doublekills                0.005504
# xpdiffat15                 0.005045
# damagetochampions          0.004962
# opp_goldat15               0.004891
# dpm                        0.004669
# damageshare                0.004509
# cspm                       0.004414
# golddiffat10               0.004387
# vspm                       0.004276
# minionkills                0.004180
# visionscore                0.004179
# goldat15                   0.003978
# total cs                   0.003975
# opp_goldat10               0.003740
# wpm                        0.003692
# opp_xpat15                 0.003297
# xpdiffat10                 0.003235
# goldat10                   0.003114
# opp_xpat10                 0.003092
# csat15                     0.003089
# wcpm                       0.003087
# xpat15                     0.003059
# opp_csat15                 0.003036
# wardsplaced                0.003013
# xpat10                     0.002993
# csat10                     0.002805
# monsterkills               0.002782
# csdiffat15                 0.002762
# controlwardsbought         0.002735
# csdiffat10                 0.002722
# monsterkillsownjungle      0.002672
# opp_csat10                 0.002581
# wardskilled                0.002485
# triplekills                0.000714
# firstblood                 0.000490
# firstbloodassist           0.000411
# firstbloodvictim           0.000388
# firstbloodkill             0.000272
# quadrakills                0.000113
# pentakills                 0.000014

# %%
#Final hyperparameter optimization to find the optimal amount of estimators.
#Using Random Forest Classifier is convenient here, because we only have to worry about tuning one parameter.

# %%
empty = ([])
for i in np.arange(100,1001,100):
    rfc = RandomForestClassifier(n_estimators = i)
    rfc.fit(X_train,y_train)
    pred_rfc = rfc.predict(X_test)
    accuracy = accuracy_score(y_test,pred_rfc)
    empty = np.append(accuracy,empty)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.

# %%
#Our final results are shown here, it appears that using 100 estimators found the highest accuracy for our model.
#Optimized final accuracy - 96.59%.

# %%
results = pd.DataFrame().assign(Estimators=np.arange(100,1001,100),Accuracy=empty)
results = results.sort_values('Accuracy',ascending=False)
results
# Out:
#    Estimators  Accuracy
# 0         100  0.965880
# 2         300  0.965699
# 3         400  0.965699
# 5         600  0.965699
# 7         800  0.965517
# 8         900  0.965336
# 4         500  0.965154
# 1         200  0.964973
# 6         700  0.964791
# 9        1000  0.964247
